# %% [markdown]
# <a href="https://colab.research.google.com/github/Smolry/Smart-HSRP-detection/blob/main/HSRP_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 61.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=YOLO('yolov8n-cls.pt')

# %%
model.train(data="/content/drive/MyDrive/dataset",epochs=30,imgsz=224,batch=16)
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics= model.val()
print(metrics)
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/drive/MyDrive/ML dataset/dataset/train... found 800 images in 2 classes ✅
# val: /content/drive/MyDrive/ML dataset/dataset/val... found 200 images in 2 classes ✅
# test: None...
# val: Fast image access ✅ (ping: 2.4±4.4 ms, read: 118.4±104.9 MB/s, size: 338.6 KB)
# val: Scanning /content/drive/MyDrive/ML dataset/dataset/val... 200 images, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 327.9Kit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 13/13 3.1it/s 4.1s
#                    all       0.98          1
# Speed: 0.1ms preprocess, 1.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/train2
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# ...

# %%
results=model.predict("/content/drive/MyDrive/ML dataset/dataset/val/hsrp/0CKYHOL_lgmnkpq7_1_47383079.jpg")
print(results[0].probs)
# Out:
# image 1/1 /content/drive/MyDrive/ML dataset/dataset/val/hsrp/0CKYHOL_lgmnkpq7_1_47383079.jpg: 224x224 hsrp 1.00, non-hsrp 0.00, 3.8ms
# Speed: 6.8ms preprocess, 3.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([9.9998e-01, 1.9887e-05], device='cuda:0')
# orig_shape: None
# shape: torch.Size([2])
# top1: 0
# top1conf: tensor(1.0000, device='cuda:0')
# top5: [0, 1]
# top5conf: tensor([9.9998e-01, 1.9887e-05], device='cuda:0')

# %%
model.train(data="/content/drive/MyDrive/ML dataset/dataset",epochs=30,imgsz=224,batch=32)
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics= model.val()
print(metrics)
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/drive/MyDrive/ML dataset/dataset/train... found 800 images in 2 classes ✅
# val: /content/drive/MyDrive/ML dataset/dataset/val... found 200 images in 2 classes ✅
# test: None...
# val: Fast image access ✅ (ping: 0.5±0.3 ms, read: 83.2±79.0 MB/s, size: 338.6 KB)
# val: Scanning /content/drive/MyDrive/ML dataset/dataset/val... 200 images, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 213.5Kit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 7/7 2.2it/s 3.2s
#                    all       0.97          1
# Speed: 0.8ms preprocess, 0.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/train32
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# ...

# %%
results=model.predict("/content/drive/MyDrive/ML dataset/dataset/val/hsrp/0CKYHOL_lgmnkpq7_1_47383079.jpg")
print(results[0].probs)
# Out:
# image 1/1 /content/drive/MyDrive/ML dataset/dataset/val/hsrp/0CKYHOL_lgmnkpq7_1_47383079.jpg: 224x224 hsrp 1.00, non-hsrp 0.00, 3.5ms
# Speed: 4.8ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([9.9998e-01, 1.9887e-05], device='cuda:0')
# orig_shape: None
# shape: torch.Size([2])
# top1: 0
# top1conf: tensor(1.0000, device='cuda:0')
# top5: [0, 1]
# top5conf: tensor([9.9998e-01, 1.9887e-05], device='cuda:0')

# %%
model.train(data="/content/drive/MyDrive/ML dataset/dataset",epochs=30,imgsz=320,batch=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2612247551.py in <cell line: 0>()
# ----> 1 model.train(data="/content/drive/MyDrive/ML dataset/dataset",epochs=30,imgsz=320,batch=16)
#
# NameError: name 'model' is not defined

# %%
model.train(data="/content/drive/MyDrive/dataset",epochs=50,imgsz=224,batch=16)
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.train(data="/content/drive/MyDrive/dataset",epochs=50,imgsz=224,batch=16)
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model=YOLO("runs/classify/train/weights/best.pt")
metrics = model.val()
print(metrics)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2652391645.py in <cell line: 0>()
# ----> 1 model=YOLO("runs/classify/train/weights/best.pt")
#       2 metrics = model.val()
#       3 print(metrics)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      81         else:
#      82             # Continue with default YOLO initialization
# ---> 83             super().__init__(model=model, task=task, verbose=verbose)
#      84             if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      85                 from ultralytics import RTDETR
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     151             self._new(model, task=task, verbose=verbose)
#     152         else:
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load training log (adjust path if needed)
results = pd.read_csv("runs/classify/train2/results.csv")

# See what columns are available
print(results.columns)

# Plot Top-1 accuracy over epochs
sns.lineplot(x=results.index, y=results['metrics/accuracy_top1'])
plt.title("Top-1 Accuracy per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()

# Plot Loss over epochs (if available)
if 'train/loss' in results.columns:
    sns.lineplot(x=results.index, y=results['train/loss'], label="Train Loss")
    if 'val/loss' in results.columns:
        sns.lineplot(x=results.index, y=results['val/loss'], label="Val Loss")
    plt.title("Loss per Epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# Plot Fitness per epoch
if 'fitness' in results.columns:
    sns.lineplot(x=results.index, y=results['fitness'])
    plt.title("Fitness per Epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Fitness")
    plt.show()
