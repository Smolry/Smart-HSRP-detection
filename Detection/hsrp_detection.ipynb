# %% [markdown]
# <a href="https://colab.research.google.com/github/Smolry/Smart-HSRP-detection/blob/main/hsrp_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path: /content/dataset  # root dataset folder
train: images/train
val: images/val


names:
  0: plate

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # start with small/nano model
model.train(data="/content/drive/MyDrive/ML dataset/ML dataset/dataset/data.yaml", epochs=50, imgsz=640, batch=16, project="/content/drive/MyDrive/ML dataset/ML dataset/runs/detect")
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("/content/drive/MyDrive/ML dataset/ML dataset/runs/detect/train/weights/best.pt")
results = model.predict("/content/drive/MyDrive/ML dataset/ML dataset/dataset/36_jpg.rf.cf75973ac12d88a9c245687a87b760af.jpg", save=True,project="/content/drive/MyDrive/ML dataset/ML dataset/yolo_predictions",name="exp1")
# Out:
# image 1/1 /content/drive/MyDrive/ML dataset/ML dataset/dataset/36_jpg.rf.cf75973ac12d88a9c245687a87b760af.jpg: 640x640 1 plate, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/drive/.shortcut-targets-by-id/1su1x2oA5GKwQ5tHgB5nva2MNhR6txGjd/ML dataset/yolo_predictions/exp12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
